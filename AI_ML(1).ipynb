# %% [markdown]
# <a href="https://colab.research.google.com/github/Eshwar1002/The-Hello-World-of-Machine-Learning/blob/main/AI_ML(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ## Define and compile the neural network

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Provide the data

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %% [markdown]
# ## Train the neural **network**

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 527ms/step - loss: 108.2900
# Epoch 2/500
# 1/1 [==============================] - 0s 13ms/step - loss: 85.2103
# Epoch 3/500
# 1/1 [==============================] - 0s 10ms/step - loss: 67.0520
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 52.7657
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 41.5257
# Epoch 6/500
# 1/1 [==============================] - 0s 12ms/step - loss: 32.6823
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 25.7246
# Epoch 8/500
# 1/1 [==============================] - 0s 11ms/step - loss: 20.2503
# Epoch 9/500
# 1/1 [==============================] - 0s 12ms/step - loss: 15.9431
# Epoch 10/500
# 1/1 [==============================] - 0s 13ms/step - loss: 12.5543
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 9.8878
# Epoch 12/500
# ...

# %% [markdown]
# ## Use the model

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 107ms/step
# [[30.995737]]
